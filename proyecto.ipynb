# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import pandas_profiling
# Out:
# /tmp/ipykernel_28222/4274494042.py:4: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling

# %%
udemy=pd.read_csv('udemy_courses.csv')
edx=pd.read_csv('edx_courses.csv')
coursera=pd.read_csv('Coursera_courses.csv')
courseraReviews=pd.read_csv('Coursera_reviews.csv')

# %% [markdown]
# Para poder entender bien los datos, vamos a ver el head de cada dataset y a estudiar los dtypes también

# %%
udemy.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
udemy.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
edx.head()
# Out:
#                                                title  \
# 0                                How to Learn Online
# 1  Programming for Everybody (Getting Started wit...
# 2            CS50's Introduction to Computer Science
# 3                                 The Analytics Edge
# 4  Marketing Analytics: Marketing Measurement Str...
#
#                                              summary n_enrolled  \
# 0  Learn essential strategies for successful onli...    124,980
# 1  This course is a "no prerequisite" introductio...    293,864
# 2  An introduction to the intellectual enterprise...  2,442,271
# 3  Through inspiring examples and stories, discov...    129,555
# 4     This course is part of a MicroMasters® Program     81,140
#
#                            course_type                            institution  \
# 0              Self-paced on your time                                    edX
# 1              Self-paced on your time             The University of Michigan
# ...

# %%
edx.dtypes
# Out:
# title                 object
# summary               object
# n_enrolled            object
# course_type           object
# institution           object
# instructors           object
# Level                 object
# subject               object
# language              object
# subtitles             object
# course_effort         object
# course_length         object
# price                 object
# course_description    object
# course_syllabus       object
# course_url            object
# dtype: object

# %%
coursera.head()
# Out:
#                                                 name  \
# 0                                   Machine Learning
# 1                                  Indigenous Canada
# 2                          The Science of Well-Being
# 3                     Technical Support Fundamentals
# 4  Become a CBRS Certified Professional Installer...
#
#                  institution  \
# 0        Stanford University
# 1      University of Alberta
# 2            Yale University
# 3                     Google
# 4  Google - Spectrum Sharing
#
#                                           course_url  \
# 0    https://www.coursera.org/learn/machine-learning
# 1   https://www.coursera.org/learn/indigenous-canada
# 2  https://www.coursera.org/learn/the-science-of-...
# 3  https://www.coursera.org/learn/technical-suppo...
# 4  https://www.coursera.org/learn/google-cbrs-cpi...
#
#                         course_id
# 0                machine-learning
# 1               indigenous-canada
# ...

# %%
coursera.dtypes
# Out:
# name           object
# institution    object
# course_url     object
# course_id      object
# dtype: object

# %%
courseraReviews.head()
# Out:
#                                              reviews       reviewers  \
# 0  Pretty dry, but I was able to pass with just t...     By Robert S
# 1  would be a better experience if the video and ...  By Gabriel E R
# 2  Information was perfect! The program itself wa...      By Jacob D
# 3  A few grammatical mistakes on test made me do ...       By Dale B
# 4  Excellent course and the training provided was...       By Sean G
#
#    date_reviews  rating                 course_id
# 0  Feb 12, 2020       4  google-cbrs-cpi-training
# 1  Sep 28, 2020       4  google-cbrs-cpi-training
# 2  Apr 08, 2020       4  google-cbrs-cpi-training
# 3  Feb 24, 2020       4  google-cbrs-cpi-training
# 4  Jun 18, 2020       4  google-cbrs-cpi-training

# %%
courseraReviews.dtypes
# Out:
# reviews         object
# reviewers       object
# date_reviews    object
# rating           int64
# course_id       object
# dtype: object

# %% [markdown]
# Vemos que hay columnas que no nos sirven a nuestro proposito (ejemplo: url del curso) por lo que vamos a eliminar las columnas que no nos aporten datos significativos para nuestros propositos.

# %%
udemy.drop(['course_id','url'],axis=1,inplace=True)
udemy.dtypes
# Out:
# course_title            object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
coursera.drop(['course_url'],axis=1,inplace=True)
coursera.dtypes
# Out:
# name           object
# institution    object
# course_id      object
# dtype: object

# %%
edx.drop(['instructors','course_syllabus','course_url'],axis=1,inplace=True)
edx.dtypes
# Out:
# title                 object
# summary               object
# n_enrolled            object
# course_type           object
# institution           object
# Level                 object
# subject               object
# language              object
# subtitles             object
# course_effort         object
# course_length         object
# price                 object
# course_description    object
# dtype: object

# %%
courseraFull=pd.merge(coursera, courseraReviews, on='course_id')

# %%
coursera['institution'].value_counts()
# Out:
# University of Pennsylvania       43
# University of Michigan           31
# Duke University                  24
# Google Cloud                     22
# IBM                              18
#                                  ..
# EDHEC Business School             1
# INSEAD                            1
# Google - Spectrum Sharing         1
# New York Institute of Finance     1
# UCL School of Management          1
# Name: institution, Length: 134, dtype: int64

# %%
#courseraReviews[(courseraReviews['reviews'].str.len()<10).index]
courseraReviews.drop(courseraReviews[courseraReviews['reviews'].str.len()<10].index,inplace=True)
courseraReviews.drop(courseraReviews[courseraReviews['reviews'].isin('NaN')],axis=0,inplace=True)

# %%
courseraReviews[courseraReviews['rating']<2]
# Out:
#                                                    reviews       reviewers  \
# 87       This course is virtually worthless. I couldn't...      By James R
# 88       This course was horrible! The Content was very...      By Sanam P
# 89       Terrible lecturer. Maybe he should retire. He ...    By Brendan F
# 90       This course was aweful! I feel like I didnt le...          By Eli
# 91       I was expecting more from the course. It is ve...  By Sebastian S
# ...                                                    ...             ...
# 1454229  Some quizzes are senseless, the course itself ...  By Mackenzie S
# 1454230  I did not receive my certificate, though have ...   By Shikha K S
# 1454231  The lessons and teachings do not match up with...     By Karl P M
# 1454232  i did'nt got my certificate and this site id v...      By ROHIT G
# 1454233  i did'nt got my certificate and this site id v...      By ROHIT G
#
#          date_reviews  rating                 course_id
# ...

# %%
courseraReviews
# Out:
#                                                    reviews  \
# 0        Pretty dry, but I was able to pass with just t...
# 1        would be a better experience if the video and ...
# 2        Information was perfect! The program itself wa...
# 3        A few grammatical mistakes on test made me do ...
# 4        Excellent course and the training provided was...
# ...                                                    ...
# 1454623                                         i liked it
# 1454669                                                NaN
# 1454678                                                NaN
# 1454691                                                NaN
# 1454700                                                NaN
#
#                   reviewers  date_reviews  rating                 course_id
# 0               By Robert S  Feb 12, 2020       4  google-cbrs-cpi-training
# 1            By Gabriel E R  Sep 28, 2020       4  google-cbrs-cpi-training
# ...
